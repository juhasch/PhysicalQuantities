# %% [markdown]
# # Autoscaling units

# %% [markdown]
# Using the `autoscale()` method, quantities can be automatically scaled:

# %%
a = 1e-3 m
a.autoscale
# Out:
# 1.0 mm

# %%
a = 0.0003 s 
a.autoscale
# Out:
# 300.0 us

# %%
a = 1.0m
a.autoscale
# Out:
# 1.0 m

# %%
# %precision 2
a = 3e-9 F
a.autoscale
# Out:
# s 4
# A 2
# m 2
# 3.00 nF
